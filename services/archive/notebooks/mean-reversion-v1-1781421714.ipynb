# %% [markdown]
# # Atrium research . mean-reversion-v1
# Period: 2026-06-07T07:21:54.255764+00:00 to 2026-06-14T07:21:54.255764+00:00
#
# Trades: 0. Delta: 0 bps.

# %%
import json
result = {
  "strategy": "mean-reversion-v1",
  "period_start": "2026-06-07T07:21:54.255764+00:00",
  "period_end": "2026-06-14T07:21:54.255764+00:00",
  "trades_count": 0,
  "baseline_collateral_usd": 0,
  "atrium_collateral_usd": 0,
  "delta_bps": 0,
  "notebook_url": "./services/archive/notebooks/mean-reversion-v1-1781421714.ipynb",
  "ipfs_cid": null,
  "publish_tx": null,
  "generated_at": "2026-06-14T07:21:54.255764+00:00",
  "publish_failed": false
}
result

# %%
trades = []  # first 10 of 0
